# %% [markdown]
# We will discuss visualization in python using two packages:
# *1* Seaborn
# *2* Bokeh

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib
import seaborn as sns
import bokeh as bk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Analysing univariate and bivariate data using seaborn
#Importing data
dm=pd.read_csv('DirectMarketing.csv')

# %%
dm.head()
# Out:
#       Age  Gender OwnHome  Married Location  Salary  Children History  \
# 0     Old  Female     Own   Single      Far   47500         0    High
# 1  Middle    Male    Rent   Single    Close   63600         0    High
# 2   Young  Female    Rent   Single    Close   13500         0     Low
# 3  Middle    Male     Own  Married    Close   85600         1    High
# 4  Middle  Female     Own   Single    Close   68400         0    High
#
#    Catalogs  AmountSpent
# 0         6          755
# 1         6         1318
# 2        18          296
# 3        18         2436
# 4        12         1304

# %%
dm.Age
# Out:
# 0         Old
# 1      Middle
# 2       Young
# 3      Middle
# 4      Middle
# 5       Young
# 6      Middle
# 7      Middle
# 8      Middle
# 9         Old
# 10      Young
# 11     Middle
# 12     Middle
# 13     Middle
# 14        Old
# 15     Middle
# 16        Old
# 17     Middle
# 18     Middle
# 19        Old
# 20      Young
# 21      Young
# 22        Old
# 23      Young
# 24      Young
# 25     Middle
# 26     Middle
# 27     Middle
# 28     Middle
# 29      Young
#         ...
# 970     Young
# 971       Old
# 972    Middle
# 973    Middle
# 974     Young
# 975    Middle
# 976    Middle
# 977    Middle
# 978    Middle
# 979    Middle
# 980       Old
# 981    Middle
# 982    Middle
# 983     Young
# 984       Old
# 985    Middle
# 986       Old
# 987       Old
# 988    Middle
# 989    Middle
# 990    Middle
# 991       Old
# 992    Middle
# 993    Middle
# 994     Young
# 995     Young
# 996    Middle
# 997       Old
# 998    Middle
# 999     Young
# Name: Age, Length: 1000, dtype: object

# %%
dm.describe()
# Out:
#               Salary    Children     Catalogs  AmountSpent
# count    1000.000000  1000.00000  1000.000000  1000.000000
# mean    56103.900000     0.93400    14.682000  1216.770000
# std     30616.314826     1.05107     6.622895   961.068613
# min     10100.000000     0.00000     6.000000    38.000000
# 25%     29975.000000     0.00000     6.000000   488.250000
# 50%     53700.000000     1.00000    12.000000   962.000000
# 75%     77025.000000     2.00000    18.000000  1688.500000
# max    168800.000000     3.00000    24.000000  6217.000000

# %%
#Data description 
dm.head(2)
# Out:
#       Age  Gender OwnHome Married Location  Salary  Children History  \
# 0     Old  Female     Own  Single      Far   47500         0    High
# 1  Middle    Male    Rent  Single    Close   63600         0    High
#
#    Catalogs  AmountSpent
# 0         6          755
# 1         6         1318

# %% [markdown]
# We will use seaborn package to do plotting.The aim here is to be able to produce most commonly used plots. We will use tthe direct marketing data set and demonstrate the features of this library. Here is the agenda:
# - Doing Univariate analysis
# - Doing bivariate analysis
# - Analyzing categorical data
# - Faceting
# - Controlling the pallets and other misc details

# %% [markdown]
# ## 1. Univariate Analysis

# %% [markdown]
# We will cover following:
# - Creating a histogram
# - Creating a density plot
# - Creating joint density plots
# - Creating joint bin plots, hexbins
# - Creating smoothed versions of bivariate density and count plots

# %% [markdown]
# We have two continous variables in our data:
#     - Salary
#     - AmountSpent
# We can understand the distribution of these two variables

# %%
sns.distplot(dm.Salary,kde=False)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dm.AmountSpent,kde=True,color='green',bins=5)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Imagine now we want to look at density estimates, distplot() will help us in doing the same!!!!

# %%
from mpl_toolkits import mplot3d

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.scatter3D(dm.Salary,dm.AmountSpent,dm.Catalogs)

# %%
sns.distplot(dm.Salary,hist=False)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dm.AmountSpent,hist=False,color='green')
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# We can also try to look at the conditional plots, lets see what happens when we look at the distribution of the Salary and AmountSpent by Gender

# %%
sns.distplot(dm.Salary[dm.Gender=="Male"],kde=False,
             color='r',axlabel="Income Distribution of Males")
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dm.Salary[dm.Gender=="Female"],kde=False,
             color='g',axlabel="Income Distribution of Females")
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Ideally there should be a way to color by gender or to create a faceted plot, we will examine this in the last section of this session

# %% [markdown]
# ### Creating a bivariate density plot

# %% [markdown]
# We use jointplot() method to create joint density/count plots

# %%
sns.jointplot(x='Salary',y='AmountSpent',data=dm)#Notice the syntax
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='Salary',y='AmountSpent',data=dm,kind='hex')
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='Salary',y='AmountSpent',data=dm,kind='kde')
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 2. Bivariate Analysis
# - Creating a simple scatter
# - Conditioning a scatter by using hues
# - Conditioning by using faceting

# %%
from sklearn import  linear_model
model = linear_model.LinearRegression()

# %%
X = dm.iloc[:, [5]].values#Salary
t = dm.iloc[:, [9]].values#AmountSpent

# %%
model.fit(X, t)
# The coefficients
print('Coefficients: \n', model.coef_)
print('Intercept:\n',model.intercept_)
# Out:
# Coefficients:
#  [[0.02196082]]
# Intercept:
#  [-15.31782541]

# %%
print(model.predict([[40000]]))
# Out:
# [[863.11510022]]

# %%
sns.lmplot(x='Salary',y='AmountSpent',data=dm)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Lets resize and get  rid of the line
sns.lmplot(x='Salary',y='AmountSpent',aspect=1.5,
           fit_reg=True,data=dm)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Let's try to get a conditional view, using Gender
sns.lmplot(x='Salary',y='AmountSpent',aspect=1.5,
           hue='Gender',data=dm,fit_reg=True)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#We can use faceting to bring in more variables
sns.lmplot(x='Salary',y='AmountSpent',hue='Gender',data=dm,
           aspect=1.5,col='Location',fit_reg=False)

# %%
sns.lmplot(x='Salary',y='AmountSpent',hue='Gender',
           data=dm,aspect=1.5,
           col='Location',
           row='Married',
           fit_reg=False)

# %%
##There are some options which can be used while faceting
sns.lmplot(x='Salary',y='AmountSpent',
           hue='Gender',
           col='Catalogs',
           aspect=1.5,
           data=dm,
           fit_reg=False)

# %%
#We can try to increase the size
sns.lmplot(x='Salary',y='AmountSpent',hue='Gender',
           col='Catalogs',aspect=1.5,data=dm,
           fit_reg=False,size=4)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Or we can try to facet wrap around column
sns.lmplot(x='Salary',y='AmountSpent',hue='Gender',col='Catalogs',aspect=1.5,data=dm,fit_reg=False,col_wrap=2) #Better!!!

# %% [markdown]
# ## 3. Analyzing Categorical Data
# - countplot
# - barplot: mean, median
# - boxplot

# %%
sns.countplot(x='Gender',data=dm)

# %%
dm.Salary.describe()
# Out:
# count      1000.000000
# mean      56103.900000
# std       30616.314826
# min       10100.000000
# 25%       29975.000000
# 50%       53700.000000
# 75%       77025.000000
# max      168800.000000
# Name: Salary, dtype: float64

# %%
#Using barplot, notice the terminologies are a liitle different
sns.barplot(x='Gender',y='Salary',data=dm)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='Gender',y='Salary',data=dm,estimator=np.median)
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='AmountSpent',data=dm)

# %%
#boxplot
sns.boxplot(x='Gender',y='AmountSpent',data=dm)

# %% [markdown]
# ## 4 Faceting
# - Using Facet_grid()to partition the plotting area
# - Using map function to produce a trellis plots

# %%
#A simple example using sns.distplot
g=sns.FacetGrid(data=dm,hue='Gender',aspect=2)
g.map(sns.distplot,'Salary',hist=True)
g.add_legend()
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#A few tweaks that we can make in FacetGrid specification
g=sns.FacetGrid(data=dm,hue='Gender',aspect=2,size=5)
g.map(sns.distplot,'Salary',hist=False)
g.add_legend()
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#A few tweaks that we can make in FacetGrid specification
g=sns.FacetGrid(data=dm,hue='Gender',
                aspect=2,
                size=5,
                xlim=[0,200000])
g.map(sns.distplot,'Salary',hist=True)
g.add_legend()
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Another example checking distribution of amount spent over Gender and Location
g=sns.FacetGrid(dm,hue='Gender',size=5,col='Location') 
g.map(plt.hist,'AmountSpent',alpha=0.6)
g.add_legend()
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 4 Controlling pallete and other misc behaviour
# - Adding titles
# - Adding x and y axis label
# - Changing xlim and ylim
# - Changing xticks and yticks
# - Changing color pallete

# %%
#Adding Titles
g=sns.distplot(dm.Salary,kde=False)
#g.set_title('Histogram',size=20,color='b',alpha=0.4)
g.axes.set_title('Histogram of Salary',
                 size=20,color='b',alpha=0.4)
g.axes.set_xlabel("Salary in $")
g.axes.set_ylabel("Amount Spent in $")
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'Amount Spent in $')

# %%
g=sns.lmplot(x='Salary',y='AmountSpent',data=dm,aspect=2)
g.ax.set_title('Scatter',size=20)
g.set_axis_labels('Salary in $','Amount Spent in $')
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g=sns.jointplot(x='Salary',y='AmountSpent',data=dm,kind='kde')
g.ax_marg_x.set_title('Jointplot',size=20)
g.set_axis_labels("Salary in $","Amount Spent in $")
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g=sns.FacetGrid(data=dm,hue='Gender',aspect=2,size=5,
                xlim=[0,200000])
g.map(sns.distplot,'Salary',hist=False)
g.add_legend()
g.ax.set_title("Hue Faceted",size=20)
g.ax.set_xlabel("Salary in $")
g.ax.set_ylabel("Density")
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(13.361467013888898, 0.5, 'Density')

# %%
#Again a strightforward case
g=sns.countplot(x='Gender',data=dm)
g.axes.set_title('Countplot',size=20)
g.axes.set_ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
#Faceted along column
g=sns.FacetGrid(dm,hue='Gender',size=5,col='Location') 
g.map(plt.hist,'AmountSpent',alpha=0.6)
g.add_legend()
g.fig.suptitle("Column Facets",size=20)
g.set_axis_labels("Amount Spent in Dollars","Count")
# Out:
# C:\Users\Dr.Srinivas\Anaconda32\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

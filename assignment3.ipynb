# %%
import pandas as pd
Data=pd.read_csv('Tips.csv', index_col=0)

# %%
Data
# Out:
#       TotalBill  Tips Smoker  Day    Time  Size
# SINO
# 1         16.99  1.01     No  Sun  Dinner   2.0
# 2         10.34  1.66     No  Sun  Dinner   3.0
# 3         21.01  3.50     No  Sun  Dinner   3.0
# 4         23.68  3.31     No  Sun  Dinner   2.0
# 5         24.59  3.61     No  Sun  Dinner   4.0
# ...         ...   ...    ...  ...     ...   ...
# 96        40.17  4.73    Yes  Fri  Dinner   4.0
# 97        27.28  4.00    Yes  Fri  Dinner   2.0
# 98        12.03  1.50    Yes  Fri  Dinner   2.0
# 99        21.01  3.00    Yes  Fri  Dinner   2.0
# 100       25.10   NaN     No  NaN   Lunch   2.0
#
# [100 rows x 6 columns]

# %%
 df1=pd.DataFrame(Data, columns= ['Time', 'TotalBill', 'Tips'] )

# %%
df1
# Out:
#         Time  TotalBill  Tips
# SINO
# 1     Dinner      16.99  1.01
# 2     Dinner      10.34  1.66
# 3     Dinner      21.01  3.50
# 4     Dinner      23.68  3.31
# 5     Dinner      24.59  3.61
# ...      ...        ...   ...
# 96    Dinner      40.17  4.73
# 97    Dinner      27.28  4.00
# 98    Dinner      12.03  1.50
# 99    Dinner      21.01  3.00
# 100    Lunch      25.10   NaN
#
# [100 rows x 3 columns]

# %%
 df2=Data[ ['Time', 'TotalBill', 'Tips'] ]

# %%
df2
# Out:
#         Time  TotalBill  Tips
# SINO
# 1     Dinner      16.99  1.01
# 2     Dinner      10.34  1.66
# 3     Dinner      21.01  3.50
# 4     Dinner      23.68  3.31
# 5     Dinner      24.59  3.61
# ...      ...        ...   ...
# 96    Dinner      40.17  4.73
# 97    Dinner      27.28  4.00
# 98    Dinner      12.03  1.50
# 99    Dinner      21.01  3.00
# 100    Lunch      25.10   NaN
#
# [100 rows x 3 columns]

# %%
 df3=Data.iloc[:,0:2]

# %%
df3
# Out:
#       TotalBill  Tips
# SINO
# 1         16.99  1.01
# 2         10.34  1.66
# 3         21.01  3.50
# 4         23.68  3.31
# 5         24.59  3.61
# ...         ...   ...
# 96        40.17  4.73
# 97        27.28  4.00
# 98        12.03  1.50
# 99        21.01  3.00
# 100       25.10   NaN
#
# [100 rows x 2 columns]

# %%
 df4=Data.loc[:, ['Time', 'TotalBill', 'Tips'] ] 
df4
# Out:
#         Time  TotalBill  Tips
# SINO
# 1     Dinner      16.99  1.01
# 2     Dinner      10.34  1.66
# 3     Dinner      21.01  3.50
# 4     Dinner      23.68  3.31
# 5     Dinner      24.59  3.61
# ...      ...        ...   ...
# 96    Dinner      40.17  4.73
# 97    Dinner      27.28  4.00
# 98    Dinner      12.03  1.50
# 99    Dinner      21.01  3.00
# 100    Lunch      25.10   NaN
#
# [100 rows x 3 columns]

# %%
Data1=pd.read_excel('Tips1.xlsx')

# %%
Data2 = pd.DataFrame.join(Data, Data1, on=None, how='left') 
Data2
# Out:
#       TotalBill  Tips Smoker  Day    Time  Size   SINO  Gender
# SINO
# 1         16.99  1.01     No  Sun  Dinner   2.0    2.0    Male
# 2         10.34  1.66     No  Sun  Dinner   3.0    3.0    Male
# 3         21.01  3.50     No  Sun  Dinner   3.0    4.0    Male
# 4         23.68  3.31     No  Sun  Dinner   2.0    5.0  Female
# 5         24.59  3.61     No  Sun  Dinner   4.0    6.0    Male
# ...         ...   ...    ...  ...     ...   ...    ...     ...
# 96        40.17  4.73    Yes  Fri  Dinner   4.0   97.0    Male
# 97        27.28  4.00    Yes  Fri  Dinner   2.0   98.0    Male
# 98        12.03  1.50    Yes  Fri  Dinner   2.0   99.0    Male
# 99        21.01  3.00    Yes  Fri  Dinner   2.0  100.0     NaN
# 100       25.10   NaN     No  NaN   Lunch   2.0    NaN     NaN
#
# [100 rows x 8 columns]

# %%
Data3=Data2.copy()

# %%
 Data3.groupby('Day')[['Tips']].aggregate(sum)
# Out:
#         Tips
# Day
# Fri    28.28
# Sat   102.79
# Sun   102.28
# Thur   41.99

# %%
 Data3.groupby(['Gender', 'Time'])['Time'].count().unstack()
# Out:
# Time    Dinner  Lunch
# Gender
# Female      23      2
# Male        56     11

# %%
 pd.crosstab(index = Data3['Gender'], columns = Data3['Time'], normalize = False)
# Out:
# Time    Dinner  Lunch
# Gender
# Female      23      2
# Male        56     11

# %%
 Data3.pivot_table('Time', index='Gender', columns=Data3.Time.values, aggfunc=len)
# Out:
#         Dinner  Lunch
# Gender
# Female      23      2
# Male        56     11

# %% [markdown]
# # Histogram
# - What is Histogram?
#     - It is a graphical representation of data using bars of different heights
#     - Histogram groups numbers into ranges and the height of each bar depicts the frequency of each range or bin
# - When to use histograms?
#     - To represent the frequency distribution of numerical variables

# %%
import matplotlib.pyplot as plt
plt.hist(Data3['TotalBill'])
# Out:
# (array([ 2., 14., 19., 30., 15.,  7.,  4.,  4.,  2.,  1.]),
#  array([ 3.07,  7.59, 12.11, 16.63, 21.15, 25.67, 30.19, 34.71, 39.23,
#         43.75, 48.27]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Data3['TotalBill'], color='green', edgecolor='white', bins=5)
# Out:
# (array([16., 49., 22.,  8.,  3.]),
#  array([ 3.07, 12.11, 21.15, 30.19, 39.23, 48.27]),
#  <a list of 5 Patch objects>)

# %%
import numpy as np
counts=[800,100,8]
day=('Friday', 'Thursday','Saturday','Sunday')
index=np.arange(len(day))

plt.bar(index, counts, color=['red','blue','cyan'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-6b18dd6a7f84> in <module>
#       4 index=np.arange(len(day))
#       5
# ----> 6 plt.bar(index, counts, color=['red','blue','cyan'])
#
# c:\users\shraddha bodake\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\shraddha bodake\appdata\local\programs\python\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\shraddha bodake\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# c:\users\shraddha bodake\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# c:\users\shraddha bodake\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
 Data3.groupby('Day').aggregate('mean')
# Out:
#       TotalBill      Tips      Size       SINO
# Day
# Fri   21.863333  3.142222  2.222222  96.000000
# Sat   18.849459  2.778108  2.487179  50.871795
# Sun   19.179091  3.196250  2.727273  27.757576
# Thur  21.220833  3.499167  2.250000  85.250000

# %%
 Data3['Tips'].mean()
# Out:
# 3.036170212765957

# %%
 Data3.groupby('Day').apply(lambda x: x.mean())
# Out:
#       TotalBill      Tips      Size       SINO
# Day
# Fri   21.863333  3.142222  2.222222  96.000000
# Sat   18.849459  2.778108  2.487179  50.871795
# Sun   19.179091  3.196250  2.727273  27.757576
# Thur  21.220833  3.499167  2.250000  85.250000

# %%
 Data3.groupby('Day').apply(mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4c2b6d4e76e8> in <module>
# ----> 1 Data3.groupby('Day').apply(mean)
#
# NameError: name 'mean' is not defined

# %%
import copy
x=[5,4,3,2,1]
y=[7,8,9]
z=[x,y]
a=copy.deepcopy(z)
b=copy.copy(z)
x[2]=6
print('a =',a,'b =',b)
# Out:
# a = [[5, 4, 3, 2, 1], [7, 8, 9]] b = [[5, 4, 6, 2, 1], [7, 8, 9]]
